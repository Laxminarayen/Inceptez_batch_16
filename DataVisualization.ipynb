# %%
# Seaborn, Matplotlib.pyplot, plotly, bokeh, d3,dash
# AWS Elastic beanstalk
#SEaborn - Top of Matplotlib.pyplot.It provides or helps you to draw high level - InformativeSTatistiacl charts

# %%
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
fifa_file = pd.read_csv("https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/fifa.csv",index_col = 'Date',parse_dates = True)

# %%
#fifa_file = fifa_file.set_index("Date")

# %%
fifa_file
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %% [markdown]
# **Line Chart**

# %%
sns.lineplot(data = fifa_file)

# %%
#Width and Height Adjustment
plt.figure(figsize = (18,10))

sns.lineplot(data = fifa_file)

# %% [markdown]
# # Steps
# ### 1. Load the data
# ### 2. Examine and understand what you will have to show or visualize?
# ### 3. Plot the data

# %%
#Seaborn
import seaborn as sns #-> Visualizations
df = pd.read_csv("https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/spotify.csv",index_col = 'Date',parse_dates = True)

# %%
df
#popularity WRT time!
# Out:
#             Shape of You  Despacito  ...    HUMBLE.  Unforgettable
# Date                                 ...
# 2017-01-06      12287078        NaN  ...        NaN            NaN
# 2017-01-07      13190270        NaN  ...        NaN            NaN
# 2017-01-08      13099919        NaN  ...        NaN            NaN
# 2017-01-09      14506351        NaN  ...        NaN            NaN
# 2017-01-10      14275628        NaN  ...        NaN            NaN
# ...                  ...        ...  ...        ...            ...
# 2018-01-05       4492978  3450315.0  ...  2685857.0      2869783.0
# 2018-01-06       4416476  3394284.0  ...  2559044.0      2743748.0
# 2018-01-07       4009104  3020789.0  ...  2350985.0      2441045.0
# 2018-01-08       4135505  2755266.0  ...  2523265.0      2622693.0
# 2018-01-09       4168506  2791601.0  ...  2727678.0      2627334.0
#
# [366 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
plt.figure(figsize = (20,10))
sns.lineplot(data = df)

# %%
plt.figure(figsize= (16,6))
plt.title("Popularity comparison 2017 and 2018 for Despacito and Unforgettable")
sns.lineplot(data = df['Despacito'],label= 'Desp')
sns.lineplot(data = df['Unforgettable'],label= 'UF')
plt.xlabel("From the release to peak popularity 2017-18")
# Out:
# Text(0.5, 0, 'From the release to peak popularity 2017-18')

# %%
plt.figure(figsize= (16,6))
plt.title("Popularity comparison 2017 and 2018 for Despacito and Unforgettable")
sns.lineplot(data = df['Despacito'],label= 'Desp')
sns.lineplot(data = df['Shape of You'],label= 'SOY')
plt.xlabel("From the release to peak popularity 2017-18")
# Out:
# Text(0.5, 0, 'From the release to peak popularity 2017-18')

# %% [markdown]
# ### 1. No. of cases per city/county - Canton - State/ Country - Validate the Source - Time based! - What kind of prediction
# ### 2. Get additional - Pop % that got vaccinated, emp pop that got vaccinated, Incidence rate, poisitivity rate, hospitalized, ICU, infection rate after vaccination, Infection sevarity - vaccination!

# %%
#BAR Plot

# %%
flight_data = pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/flight_delays.csv',index_col = 'Month')

# %%
flight_data.tail()
# Out:
#              AA        AS         B6  ...  US         VX        WN
# Month                                 ...
# 8      3.193907  2.503899   9.280950  ... NaN   5.106221  5.532108
# 9     -1.432732 -1.813800   3.539154  ... NaN   0.070998 -1.336260
# 10    -0.580930 -2.993617   3.676787  ... NaN   2.254278 -0.688851
# 11     0.772630 -1.916516   1.418299  ... NaN   0.116370  0.995684
# 12     4.149684 -1.846681  13.839290  ... NaN  13.498720  6.720893
#
# [5 rows x 14 columns]

# %%
plt.figure(figsize= (16,6))
plt.title("Average Arrival delay for Inceptez Airlines WN, by month")

#defenition for the bar 
sns.barplot(x = flight_data.index, y = flight_data['WN'])

#Adding labels 
plt.ylabel("Arrival delay in mins")
plt.xlabel("The months as integers")
# Out:
# Text(0.5, 0, 'The months as integers')

# %%
#Try for NK

# %%
##Heatmap 
plt.figure(figsize= (8,8))
plt.title("Average Arrival delay for Inceptez Airlines WN, by month")

#defenition for the heatmap - the magnitude of each location monthwise as colours
sns.heatmap(data = flight_data,annot= True,vmin = -10,vmax = 35,cmap='YlGnBu')
#Adding labels 
plt.ylabel("Arrival delay in mins")
plt.xlabel("The months as integers")
# Out:
# Text(0.5, 51.0, 'The months as integers')

# %%
#Correlation matrix
flight_data.corr()
# Out:
#           AA        AS        B6  ...        US        VX        WN
# AA  1.000000  0.334980  0.429854  ...  0.823713  0.425237  0.615664
# AS  0.334980  1.000000  0.340359  ...  0.489025  0.229571  0.519228
# B6  0.429854  0.340359  1.000000  ...  0.788345  0.579750  0.151750
# DL  0.805229  0.394359  0.643313  ...  0.821757  0.700605  0.691805
# EV  0.896523  0.356608  0.342627  ...  0.669736  0.462638  0.730115
# F9  0.903986  0.336791  0.510718  ...  0.878874  0.308397  0.465765
# HA  0.220065  0.684979  0.467905  ...  0.586160 -0.008439 -0.007296
# MQ  0.842701  0.283977  0.529724  ...  0.660181  0.150111  0.239744
# NK  0.573716  0.480863  0.032038  ...  0.293515  0.395419  0.742869
# OO  0.620477  0.350657  0.591115  ...  0.590313  0.561515  0.548304
# UA  0.809874  0.457414  0.233021  ...  0.477816  0.536968  0.926800
# US  0.823713  0.489025  0.788345  ...  1.000000  0.333396  0.242344
# VX  0.425237  0.229571  0.579750  ...  0.333396  1.000000  0.630278
# ...

# %%
##Heatmap 
plt.figure(figsize= (10,10))
plt.title("Average Arrival delay for Inceptez Airlines WN, by month")

#defenition for the heatmap - the magnitude of each location monthwise as colours
corr = flight_data.corr()
sns.heatmap(data = corr,annot= True,vmin = -1, vmax = 1)
#Adding labels 
plt.ylabel("Arrival delay in mins")
plt.xlabel("The months as integers")
# Out:
# Text(0.5, 69.0, 'The months as integers')

# %%
insurance = pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/insurance.csv')

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x=insurance['age'],y= insurance['charges'])

# %%
sns.scatterplot(x=insurance['bmi'],y= insurance['charges'])

# %%
sns.scatterplot(x=insurance['children'],y= insurance['charges'])

# %%
sns.scatterplot(x=insurance['age'],y= insurance['charges'],hue = insurance['smoker'])

# %%
sns.scatterplot(x=insurance['bmi'],y= insurance['charges'],hue = insurance['smoker'])

# %%
sns.regplot(x=insurance['bmi'],y= insurance['charges'])

# %%
sns.lmplot(x='bmi',y= 'charges',hue = 'smoker',data = insurance)

# %%
sns.swarmplot(x = insurance['smoker'],y = insurance['charges'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.pairplot(insurance)

# %%
#Distribution Plots
iris = pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/iris.csv',index_col = 'Id')

# %%
iris
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  ...  Petal Width (cm)         Species
# Id                                        ...
# 1                  5.1               3.5  ...               0.2     Iris-setosa
# 2                  4.9               3.0  ...               0.2     Iris-setosa
# 3                  4.7               3.2  ...               0.2     Iris-setosa
# 4                  4.6               3.1  ...               0.2     Iris-setosa
# 5                  5.0               3.6  ...               0.2     Iris-setosa
# ..                 ...               ...  ...               ...             ...
# 146                6.7               3.0  ...               2.3  Iris-virginica
# 147                6.3               2.5  ...               1.9  Iris-virginica
# 148                6.5               3.0  ...               2.0  Iris-virginica
# 149                6.2               3.4  ...               2.3  Iris-virginica
# ...

# %%
sns.distplot(a = iris['Petal Length (cm)'],kde = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(data=iris['Petal Length (cm)'],shade = True)

# %%
sns.jointplot(x = iris['Petal Length (cm)'], y = iris['Petal Width (cm)'],kind = 'kde')

# %% [markdown]
# ![seaborn.png](data:image/png;base64,...)

# %% [markdown]
# ![EKLyG1NW4AU6nno.jpeg](data:image/jpeg;base64,...)

# %%
dickt = {
    'data':['a','am','p','pm'],
    'foo':['dfff','dfdfd','dssd','']
}

# %%
pd.DataFrame(dickt).to_csv("want_to_eliminate_list.csv",index = False)
# Out:
#   data    foo
# 0    a   dfff
# 1   am  dfdfd
# 2    p   dssd
# 3   pm
